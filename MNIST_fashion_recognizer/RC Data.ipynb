# %%
def collect_full_results():
    total_num_profiles = 1757
    url_base = "https://www.recurse.com/api/v1/profiles?"
    offset = 0
    limit = 15
    full_results = []
    while len(full_results) < total_num_profiles:
        sleep(0.9)
        query_string = urlencode(dict(offset=offset, limit=limit))
        url = url_base + query_string
        response = requests.get(url, headers=headers)
        full_results.extend(response.json())
        offset += limit
    return full_results

# %%
collect_full_results()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8b13cecc092a> in <module>
# ----> 1 collect_full_results()
#
# <ipython-input-2-173d2b398361> in collect_full_results()
#       6     full_results = []
#       7     while len(full_results) < total_num_profiles:
# ----> 8         sleep(0.9)
#       9         query_string = urlencode(dict(offset=offset, limit=limit))
#      10         url = url_base + query_string
#
# NameError: name 'sleep' is not defined

# %%
import os
os.getcwd()
# !cd ../
os.getcwd()
# Out:
# '/Users/christinejiang/Documents/Python/personal_projects/MNIST_fashion_recognizer'

# %%
import pandas as pd
pd.read_pickle('../../../../Downloads/1586982421264891000_full.pickle')
# Out:
#                                            before_rc_hl before_rc_match  \
# 0     Founder of Ksplice (rebootless kernel updates)...            None
# 1                                                  None            None
# 2     I worked at Kickstarter as a full-stack engine...            None
# 3                 Python, Flask, Django, Docker, Nagois            None
# 4     I worked with a few startups building apps, au...            None
# ...                                                 ...             ...
# 1752  * 2.5 years as an institutional investor (aka ...            None
# 1753          physics PhD dropout, security engineering            None
# 1754  I was a Design Lead at Jet.com and Walmart. I ...            None
# 1755                                               None            None
# 1756                                               None            None
#
#                                      before_rc_rendered  \
# 0     <p>Founder of Ksplice (rebootless kernel updat...
# 1
# 2     <p>I worked at Kickstarter as a full-stack eng...
# 3        <p>Python, Flask, Django, Docker, Nagois</p>\n
# 4     <p>I worked with a few startups building apps,...
# ...                                                 ...
# 1752  <ul>\n<li>2.5 years as an institutional invest...
# 1753  <p>physics PhD dropout, security engineering</...
# 1754  <p>I was a Design Lead at Jet.com and Walmart....
# 1755
# 1756
#
#                                     before_rc_truncated bio_hl bio_match  \
# 0     Founder of Ksplice (rebootless kernel updates)...   None      None
# 1                                                  None             None
# 2     I worked at Kickstarter as a full-stack engine...   None      None
# 3                 Python, Flask, Django, Docker, Nagois   None      None
# 4     I worked with a few startups building apps, au...   None      None
# ...                                                 ...    ...       ...
# 1752  * 2.5 years as an institutional investor (aka ...   None      None
# 1753          physics PhD dropout, security engineering   None      None
# 1754  I was a Design Lead at Jet.com and Walmart. I ...   None      None
# 1755                                               None   None      None
# 1756                                               None   None      None
#
#      bio_rendered bio_truncated                                   company  \
# 0                          None  {'id': 972, 'name': 'Kandra Labs, Inc.'}
# 1                                                                     NaN
# 2                          None           {'id': 2243, 'name': 'Paradox'}
# 3                          None                                       NaN
# 4                          None             {'id': 1265, 'name': 'Monzo'}
# ...           ...           ...                                       ...
# 1752                       None                                       NaN
# 1753                       None                                       NaN
# 1754                       None                                       NaN
# 1755                       None              {'id': 299, 'name': 'Artsy'}
# 1756                       None                                       NaN
#
#                                        current_location  ...  \
# 0     {'id': 22419, 'name': 'San Francisco, CA', 'sh...  ...
# 1     {'id': 21799, 'name': 'New York City, NY', 'sh...  ...
# 2     {'id': 21726, 'name': 'Brooklyn, NY', 'short_n...  ...
# 3     {'id': 8251, 'name': 'Accra, Ghana', 'short_na...  ...
# 4     {'id': 7744, 'name': 'London, United Kingdom',...  ...
# ...                                                 ...  ...
# 1752  {'id': 21799, 'name': 'New York City, NY', 'sh...  ...
# 1753  {'id': 22419, 'name': 'San Francisco, CA', 'sh...  ...
# 1754  {'id': 2797, 'name': 'Toronto, Canada', 'short...  ...
# 1755                                                NaN  ...
# 1756  {'id': 22419, 'name': 'San Francisco, CA', 'sh...  ...
#
#        phone_number_rendered phone_number_truncated             pronouns  \
# 0      <p>703-859-1830</p>\n           703-859-1830                 None
# 1        <p>8148601795</p>\n             8148601795                 None
# 2      <p>626-487-4511</p>\n           626-487-4511  He/his | They/their
# 3                                                                 he/him
# 4     <p>+447398681879</p>\n          +447398681879               He/His
# ...                      ...                    ...                  ...
# 1752     <p>9174353373</p>\n             9174353373                 None
# 1753     <p>3143970911</p>\n             3143970911                 None
# 1754   <p>412-638-2398</p>\n           412-638-2398               He/his
# 1755                                                                None
# 1756     <p>6287588099</p>\n             6287588099              She/her
#
#      results_count                       slug  \
# 0             1757            1421-tim-abbott
# 1             1757         1146-ahmed-abdalla
# 2             1757         3537-brian-abelson
# 3             1757  3696-anthony-anabila-abeo
# 4             1757           2257-jaseem-abid
# ...            ...                        ...
# 1752          1757             2997-kevin-zhu
# 1753          1757               1514-yan-zhu
# 1754          1757            2707-ari-zilnik
# 1755          1757          361-damon-zucconi
# 1756          1757        2755-elsa-zuckerman
#
#                                                  stints         twitter  \
# 0     [{'id': 989, 'type': 'residency', 'title': Non...            None
# 1     [{'id': 640, 'type': 'retreat', 'title': None,...  simplyahmaz1ng
# 2     [{'id': 2121, 'type': 'retreat', 'title': None...     abelsonlive
# 3     [{'id': 2390, 'type': 'retreat', 'title': None...    anthonyabeo7
# 4     [{'id': 1206, 'type': 'retreat', 'title': None...      jaseemabid
# ...                                                 ...             ...
# 1752  [{'id': 1752, 'type': 'retreat', 'title': None...            None
# 1753  [{'id': 38, 'type': 'residency', 'title': None...          bcrypt
# 1754  [{'id': 1562, 'type': 'retreat', 'title': None...         azilnik
# 1755  [{'id': 147, 'type': 'retreat', 'title': None,...        dzucconi
# 1756  [{'id': 1595, 'type': 'retreat', 'title': None...            None
#
#      unformatted_phone_number                              zoom_url  \
# 0                +17038591830                                  None
# 1                +18148601795                                  None
# 2                +16264874511                                  None
# 3                        None  https://us04web.zoom.us/j/5636082962
# 4               +447398681879                                  None
# ...                       ...                                   ...
# 1752             +19174353373                                  None
# 1753             +13143970911                                  None
# 1754             +14126382398                                  None
# 1755                     None                                  None
# 1756             +16287588099                                  None
#
#      most_recent_date
# 0          2016-11-21
# 1          2016-03-28
# 2          2019-09-23
# 3          2020-03-30
# 4          2017-05-22
# ...               ...
# 1752       2019-01-07
# 1753       2016-07-16
# 1754       2018-04-02
# 1755       2013-06-03
# 1756       2018-07-02
#
# [1757 rows x 52 columns]
