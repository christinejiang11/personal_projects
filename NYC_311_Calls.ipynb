# %%
import pandas as pd
import numpy as np
import requests
from sodapy import Socrata
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#goals of this project
#work with API
#work with jsons
#learn threading / parallelization
#data cleaning
#potentially set up sql database
#bokeh dashboard / work with geospatial data

# %%
#define parameters for endpoint, dataset, and app token
data_url = 'data.cityofnewyork.us'
dataset = 'erm2-nwe9'
app_token = 'dM7DDeidbAmgtydtJVV1epbiU'

#sets up the connection, need application token to override throttling limits
#username and password only required for creating or modifying data
client = Socrata(data_url, app_token)
client.timeout = 6000

#create a loop to download the first 8000 records, save records in a dataframe
start = 0
chunk_size = 2000
results = []
while True:
    print(start)
    results.extend(client.get(dataset, limit=chunk_size))
    start = start+chunk_size
    if (start > 6000): #int(record_count[0]['COUNT'])):
        break
        
df = pd.DataFrame(results)
# Out:
# 0
# 2000
# 4000
# 6000

# %%
#count number of records in dataset
record_count = client.get(dataset, select='COUNT(*)')
record_count
# Out:
# [{'COUNT': '22725530'}]

# %%
#export downloaded data to csv for later access
df.to_csv('../data/311_data.csv', index=False)
newdata = pd.read_csv('../data/311_data.csv')
newdata
# Out:
#       unique_key             created_date agency  \
# 0       46070760  2020-04-27T02:00:02.000   NYPD
# 1       46071314  2020-04-27T01:59:21.000   NYPD
# 2       46071244  2020-04-27T01:54:23.000   NYPD
# 3       46070650  2020-04-27T01:51:16.000   NYPD
# 4       46073379  2020-04-27T01:48:47.000    DHS
# ...          ...                      ...    ...
# 7995    46074138  2020-04-26T14:32:49.000    HPD
# 7996    46072197  2020-04-26T14:32:33.000   NYPD
# 7997    46073186  2020-04-26T14:32:09.000    DCA
# 7998    46071419  2020-04-26T14:31:14.000    HPD
# 7999    46073319  2020-04-26T14:31:00.000    DEP
#
#                                             agency_name  \
# 0                       New York City Police Department
# 1                       New York City Police Department
# 2                       New York City Police Department
# 3                       New York City Police Department
# 4                       Department of Homeless Services
# ...                                                 ...
# 7995  Department of Housing Preservation and Develop...
# 7996                    New York City Police Department
# 7997                     Department of Consumer Affairs
# 7998  Department of Housing Preservation and Develop...
# 7999             Department of Environmental Protection
#
#                   complaint_type           descriptor  \
# 0            Noise - Residential         Loud Talking
# 1                Illegal Parking      Blocked Hydrant
# 2            Noise - Residential      Loud Television
# 3            Noise - Residential     Banging/Pounding
# 4     Homeless Person Assistance                  NaN
# ...                          ...                  ...
# 7995                    PLUMBING         WATER SUPPLY
# 7996             Illegal Parking      Blocked Hydrant
# 7997          Consumer Complaint         Retail Store
# 7998              HEAT/HOT WATER      ENTIRE BUILDING
# 7999                       Noise  Noise: Alarms (NR3)
#
#                    location_type  incident_zip        incident_address  \
# 0     Residential Building/House       10473.0  635 CASTLE HILL AVENUE
# 1                Street/Sidewalk       11225.0   460 MONTGOMERY STREET
# 2     Residential Building/House       10009.0    309 EAST    8 STREET
# 3     Residential Building/House       10040.0      99 HILLSIDE AVENUE
# 4                            NaN       11212.0    159 EAST   96 STREET
# ...                          ...           ...                     ...
# 7995        RESIDENTIAL BUILDING       11226.0     2305 BEDFORD AVENUE
# 7996             Street/Sidewalk       10467.0     3039 WALLACE AVENUE
# 7997                         NaN       11385.0          71-62 69 PLACE
# 7998        RESIDENTIAL BUILDING       10457.0    1511 SHERIDAN AVENUE
# 7999                         NaN       11209.0           521 72 STREET
#
#              street_name  ...              closed_date  \
# 0     CASTLE HILL AVENUE  ...                      NaN
# 1      MONTGOMERY STREET  ...                      NaN
# 2       EAST    8 STREET  ...                      NaN
# 3        HILLSIDE AVENUE  ...                      NaN
# 4       EAST   96 STREET  ...                      NaN
# ...                  ...  ...                      ...
# 7995      BEDFORD AVENUE  ...                      NaN
# 7996      WALLACE AVENUE  ...  2020-04-26T14:42:02.000
# 7997            69 PLACE  ...                      NaN
# 7998     SHERIDAN AVENUE  ...                      NaN
# 7999           72 STREET  ...                      NaN
#
#                                  resolution_description  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7995  The following complaint conditions are still o...
# 7996  The Police Department responded and upon arriv...
# 7997                                                NaN
# 7998  The complaint you filed is a duplicate of a co...
# 7999                                                NaN
#
#      resolution_action_updated_date address_type facility_type  \
# 0                               NaN          NaN           NaN
# 1                               NaN          NaN           NaN
# 2                               NaN          NaN           NaN
# 3                               NaN          NaN           NaN
# 4                               NaN          NaN           NaN
# ...                             ...          ...           ...
# 7995        2020-04-26T00:00:00.000      ADDRESS           NaN
# 7996        2020-04-26T18:42:06.000          NaN           NaN
# 7997                            NaN          NaN           NaN
# 7998        2020-04-26T00:00:00.000      ADDRESS           NaN
# 7999                            NaN      ADDRESS           NaN
#
#      bridge_highway_direction road_ramp bridge_highway_segment  \
# 0                         NaN       NaN                    NaN
# 1                         NaN       NaN                    NaN
# 2                         NaN       NaN                    NaN
# 3                         NaN       NaN                    NaN
# 4                         NaN       NaN                    NaN
# ...                       ...       ...                    ...
# 7995                      NaN       NaN                    NaN
# 7996                      NaN       NaN                    NaN
# 7997                      NaN       NaN                    NaN
# 7998                      NaN       NaN                    NaN
# 7999                      NaN       NaN                    NaN
#
#       taxi_company_borough taxi_pick_up_location
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ...                    ...                   ...
# 7995                   NaN                   NaN
# 7996                   NaN                   NaN
# 7997                   NaN                   NaN
# 7998                   NaN                   NaN
# 7999                   NaN                   NaN
#
# [8000 rows x 43 columns]

# %%
newdata.columns
# Out:
# Index(['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'city', 'landmark',
#        'status', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'latitude', 'longitude', 'location', ':@computed_region_efsh_h5xi',
#        ':@computed_region_f5dn_yrer', ':@computed_region_yeji_bk3q',
#        ':@computed_region_92fq_4b7q', ':@computed_region_sbqj_enih',
#        'closed_date', 'resolution_description',
#        'resolution_action_updated_date', 'address_type', 'facility_type',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'taxi_company_borough', 'taxi_pick_up_location'],
#       dtype='object')

# %%
plt.rc('figure',figsize=(20,4))
sns.heatmap(newdata.isnull())

# %%
pd.options.display.max_columns=50
newdata.head()
newdata['count']=1

# %%
newdata.head()
# Out:
#    unique_key             created_date agency  \
# 0    46070760  2020-04-27T02:00:02.000   NYPD
# 1    46071314  2020-04-27T01:59:21.000   NYPD
# 2    46071244  2020-04-27T01:54:23.000   NYPD
# 3    46070650  2020-04-27T01:51:16.000   NYPD
# 4    46073379  2020-04-27T01:48:47.000    DHS
#
#                        agency_name              complaint_type  \
# 0  New York City Police Department         Noise - Residential
# 1  New York City Police Department             Illegal Parking
# 2  New York City Police Department         Noise - Residential
# 3  New York City Police Department         Noise - Residential
# 4  Department of Homeless Services  Homeless Person Assistance
#
#          descriptor               location_type  incident_zip  \
# 0      Loud Talking  Residential Building/House       10473.0
# 1   Blocked Hydrant             Street/Sidewalk       11225.0
# 2   Loud Television  Residential Building/House       10009.0
# 3  Banging/Pounding  Residential Building/House       10040.0
# 4               NaN                         NaN       11212.0
#
#          incident_address         street_name  cross_street_1  \
# 0  635 CASTLE HILL AVENUE  CASTLE HILL AVENUE  RANDALL AVENUE
# 1   460 MONTGOMERY STREET   MONTGOMERY STREET      CLOVE ROAD
# 2    309 EAST    8 STREET    EAST    8 STREET        AVENUE B
# 3      99 HILLSIDE AVENUE     HILLSIDE AVENUE            BEND
# 4    159 EAST   96 STREET    EAST   96 STREET    RUTLAND ROAD
#
#        cross_street_2 intersection_street_1 intersection_street_2      city  \
# 0  CINCINNATUS AVENUE        RANDALL AVENUE    CINCINNATUS AVENUE     BRONX
# 1     NEW YORK AVENUE            CLOVE ROAD       NEW YORK AVENUE  BROOKLYN
# 2            AVENUE C              AVENUE B              AVENUE C  NEW YORK
# 3      SICKLES STREET                  BEND        SICKLES STREET  NEW YORK
# 4     WINTHROP STREET          RUTLAND ROAD       WINTHROP STREET  BROOKLYN
#
#              landmark       status community_board           bbl    borough  \
# 0  CASTLE HILL AVENUE  In Progress        09 BRONX  2.035700e+09      BRONX
# 1   MONTGOMERY STREET  In Progress     09 BROOKLYN  3.013090e+09   BROOKLYN
# 2    EAST    8 STREET  In Progress    03 MANHATTAN  1.003910e+09  MANHATTAN
# 3     HILLSIDE AVENUE  In Progress    12 MANHATTAN  1.021700e+09  MANHATTAN
# 4    EAST   96 STREET  In Progress     17 BROOKLYN  3.046150e+09   BROOKLYN
#
#    x_coordinate_state_plane  y_coordinate_state_plane open_data_channel_type  \
# 0                 1026240.0                  238099.0                 MOBILE
# 1                  998249.0                  181673.0                 MOBILE
# 2                  989800.0                  203546.0                 ONLINE
# 3                 1004433.0                  252528.0                 MOBILE
# 4                 1005571.0                  180696.0                  PHONE
#
#   park_facility_name park_borough   latitude  longitude  \
# 0        Unspecified        BRONX  40.820103 -73.848292
# 1        Unspecified     BROOKLYN  40.665316 -73.949540
# 2        Unspecified    MANHATTAN  40.725362 -73.979977
# 3        Unspecified    MANHATTAN  40.859783 -73.927036
# 4        Unspecified     BROOKLYN  40.662620 -73.923150
#
#                                             location  \
# 0  {'latitude': '40.82010259053273', 'longitude':...
# 1  {'latitude': '40.6653160788034', 'longitude': ...
# 2  {'latitude': '40.725361711692024', 'longitude'...
# 3  {'latitude': '40.85978272320349', 'longitude':...
# 4  {'latitude': '40.6626198266009', 'longitude': ...
#
#    :@computed_region_efsh_h5xi  :@computed_region_f5dn_yrer  \
# 0                      11611.0                         58.0
# 1                      13509.0                         17.0
# 2                      11729.0                         70.0
# 3                      13098.0                         47.0
# 4                      17614.0                         61.0
#
#    :@computed_region_yeji_bk3q  :@computed_region_92fq_4b7q  \
# 0                          5.0                         31.0
# 1                          2.0                         48.0
# 2                          4.0                         50.0
# 3                          4.0                         39.0
# 4                          2.0                         17.0
#
#    :@computed_region_sbqj_enih closed_date resolution_description  \
# 0                         26.0         NaN                    NaN
# 1                         44.0         NaN                    NaN
# 2                          5.0         NaN                    NaN
# 3                         22.0         NaN                    NaN
# 4                         40.0         NaN                    NaN
#
#   resolution_action_updated_date address_type  facility_type  \
# 0                            NaN          NaN            NaN
# 1                            NaN          NaN            NaN
# 2                            NaN          NaN            NaN
# 3                            NaN          NaN            NaN
# 4                            NaN          NaN            NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment  \
# 0                      NaN       NaN                    NaN
# 1                      NaN       NaN                    NaN
# 2                      NaN       NaN                    NaN
# 3                      NaN       NaN                    NaN
# 4                      NaN       NaN                    NaN
#
#   taxi_company_borough taxi_pick_up_location  count
# 0                  NaN                   NaN      1
# 1                  NaN                   NaN      1
# 2                  NaN                   NaN      1
# 3                  NaN                   NaN      1
# 4                  NaN                   NaN      1

# %%
sns.barplot(x='agency_name',y='count',data=newdata, estimator=sum)

# %%
sns.barplot(x='complaint_type',y='count',data=newdata, estimator=sum)

# %%
test = pd.Series(newdata.groupby('complaint_type')['unique_key'].count().sort_values(ascending=False)[0:10])
sns.barplot(test.index, test.values)
